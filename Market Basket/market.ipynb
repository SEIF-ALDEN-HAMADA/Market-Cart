# %% [markdown]
# # 🛒 Market Basket Analysis using Apriori Algorithm
# This notebook analyzes shopping transaction data using the Apriori algorithm to find associations between items.

# %% [markdown]
# ## 🔹 Step 1: Load the Data

# %%
import pandas as pd

df = pd.read_csv("Dataset.csv")

df.head()
# Out:
#            shrimp    almonds     avocado    vegetables mix green grapes  \
# 0         burgers  meatballs        eggs               NaN          NaN
# 1         chutney        NaN         NaN               NaN          NaN
# 2          turkey    avocado         NaN               NaN          NaN
# 3   mineral water       milk  energy bar  whole wheat rice    green tea
# 4  low fat yogurt        NaN         NaN               NaN          NaN
#
#   whole weat flour yams cottage cheese energy drink tomato juice  \
# 0              NaN  NaN            NaN          NaN          NaN
# 1              NaN  NaN            NaN          NaN          NaN
# 2              NaN  NaN            NaN          NaN          NaN
# 3              NaN  NaN            NaN          NaN          NaN
# 4              NaN  NaN            NaN          NaN          NaN
#
#   low fat yogurt green tea honey salad mineral water salmon antioxydant juice  \
# 0            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 1            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 2            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 3            NaN       NaN   NaN   NaN           NaN    NaN               NaN
# 4            NaN       NaN   NaN   NaN           NaN    NaN               NaN
#
#   frozen smoothie spinach  olive oil
# 0             NaN     NaN        NaN
# 1             NaN     NaN        NaN
# 2             NaN     NaN        NaN
# 3             NaN     NaN        NaN
# 4             NaN     NaN        NaN

# %% [markdown]
# ## 🔹 Step 2: Convert Each Row to a List of Items

# %%
transactions = df.apply(lambda row: row.dropna().tolist(), axis=1).tolist()

transactions[:5]
# Out:
# [['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt']]

# %% [markdown]
# ## 🔹 Step 3: Split Data into Training and Testing Sets

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(transactions, test_size=0.2, random_state=42)

# %% [markdown]
# ## 🔹 Step 4: Convert Training Data to True/False Table

# %%
! pip install mlxtend
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.15.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (2.2.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas>=0.24.2->mlxtend) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\tvs21\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\tvs21\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
train_array = te.fit(train).transform(train)
train_df = pd.DataFrame(train_array, columns=te.columns_)
train_df.head()
# Out:
#    almonds  antioxydant juice  asparagus  avocado  babies food  bacon  \
# 0    False              False      False    False        False  False
# 1    False              False      False    False        False  False
# 2    False              False      False    False        False  False
# 3    False              False      False    False        False  False
# 4    False              False      False    False        False  False
#
#    barbecue sauce  black tea  blueberries  body spray  ...  turkey  \
# 0           False      False        False       False  ...   False
# 1           False      False        False       False  ...   False
# 2           False      False        False       False  ...   False
# 3           False      False        False       False  ...   False
# 4           False      False        False       False  ...   False
#
#    vegetables mix  water spray  white wine  whole weat flour  \
# 0           False        False       False             False
# 1           False        False       False             False
# 2           False        False       False             False
# 3           False        False       False             False
# 4           False        False       False             False
#
#    whole wheat pasta  whole wheat rice   yams  yogurt cake  zucchini
# 0              False             False  False        False     False
# 1              False             False  False        False     False
# 2              False             False  False        False     False
# 3              False             False  False        False     False
# 4              False             False  False        False     False
#
# [5 rows x 119 columns]

# %% [markdown]
# ## 🔹 Step 5: Find Frequent Itemsets

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(train_df, min_support=0.05, use_colnames=True)


frequent_itemsets
# Out:
#      support                    itemsets
# 0   0.087500                   (burgers)
# 1   0.078167                      (cake)
# 2   0.060500                   (chicken)
# 3   0.163000                 (chocolate)
# 4   0.078833                   (cookies)
# 5   0.050667               (cooking oil)
# 6   0.176333                      (eggs)
# 7   0.078667                  (escalope)
# 8   0.167500              (french fries)
# 9   0.062833           (frozen smoothie)
# 10  0.097833         (frozen vegetables)
# 11  0.051500             (grated cheese)
# 12  0.133667                 (green tea)
# 13  0.101667               (ground beef)
# 14  0.076000            (low fat yogurt)
# 15  0.127667                      (milk)
# 16  0.240333             (mineral water)
# 17  0.066667                 (olive oil)
# 18  0.099667                  (pancakes)
# 19  0.073333                    (shrimp)
# 20  0.053167                      (soup)
# 21  0.177833                 (spaghetti)
# 22  0.069333                  (tomatoes)
# 23  0.062500                    (turkey)
# 24  0.060667          (whole wheat rice)
# 25  0.052667  (mineral water, chocolate)
# 26  0.061833  (mineral water, spaghetti)

# %% [markdown]
# ## 🔹 Step 6: Create If-Then Rules

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, support, confidence, lift]
# Index: []

# %% [markdown]
# ##  ظ🔹   Step 7: Check the Rules on Unseen Data

# %%
cleaned_test = [[item.strip().lower() for item in basket] for basket in test]

def rule_applies(rule, transaction):
    return rule.issubset(set(transaction))

evaluated_rules = []

for i, row in rules.iterrows():
    ant = set([item.strip().lower() for item in row['antecedents']])
    con = set([item.strip().lower() for item in row['consequents']])
    
    matched = [t for t in cleaned_test if rule_applies(ant, t)]
    success = [t for t in matched if rule_applies(con, t)]

    if matched:
        test_conf = len(success) / len(matched)
        evaluated_rules.append({
            'antecedents': ant,
            'consequents': con,
            'test_confidence': round(test_conf, 2)
        })

pd.DataFrame(evaluated_rules)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
